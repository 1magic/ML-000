# %%
# !pip install lightgbm xgboost catboost category-encoders sklearn pandas==1.1.5

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# drive_path = 'drive/MyDrive/深度学习/机器学习训练营/final/'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import missingno as msno
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import lightgbm as lgb

# %%
drive_path = 'final/'

# %% [markdown]
# ## data

# %%
train = pd.read_csv(drive_path + 'train_final.csv')
test = pd.read_csv(drive_path + 'test_final.csv')

# %%
train_dataset = lgb.Dataset(train.drop(columns='loan_status'), train['loan_status'])
test_dataset = lgb.Dataset(test.drop(columns='loan_status'), test['loan_status'])

# %% [markdown]
# ## LGBM

# %%
import io
import multiprocessing
from contextlib import redirect_stdout
from copy import deepcopy
from dataclasses import dataclass, asdict
import hyperopt.pyll
from hyperopt import fmin, tpe, hp
from hyperopt import space_eval
import numpy as np
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

import copy
cpu_count = 4
use_gpu = False
@dataclass
class LGBOpt:
    num_threads: any = hp.choice('num_threads', [cpu_count])
    num_leaves: any = hp.choice('num_leaves', [30,40,50,60,70,80,90,100,110,120,130,140])
    metric: any = hp.choice('metric', ['binary_error'])
    num_round: any = hp.choice('num_rounds', [1500])
    objective: any = hp.choice('objective', ['binary'])
    learning_rate: any = hp.uniform('learning_rate', 0.01, 0.1)
    feature_fraction: any = hp.uniform('feature_fraction', 0.5, 1.0)
    bagging_fraction: any = hp.uniform('bagging_fraction', 0.8, 1.0)
    device_type: any = hp.choice('device_tpye', ['gpu']) if use_gpu else hp.choice('device_type',
                                                                                   ['cpu'])
    boosting: any = hp.choice('boosting', ['gbdt', 'dart', 'goss'])
    extra_trees: any = hp.choice('extra_tress', [False, True])
    drop_rate: any = hp.uniform('drop_rate', 0, 0.2)
    uniform_drop: any = hp.choice('uniform_drop', [True, False])
    lambda_l1: any = hp.uniform('lambda_l1', 0, 10)  # TODO: Check range
    lambda_l2: any = hp.uniform('lambda_l2', 0, 10)  # TODO: Check range
    min_gain_to_split: any = hp.uniform('min_gain_to_split', 0, 1)  # TODO: Check range
    min_data_in_bin = hp.choice('min_data_in_bin', [3, 5, 10, 15, 20, 50])

    @staticmethod
    def get_common_params():
        return {'num_thread': 4, 'num_leaves': 12, 'metric': 'binary', 'objective': 'binary',
                'num_round': 1000, 'learning_rate': 0.01, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}

# %%
class FitterBase(object):
    def __init__(self, label, metric, max_eval=100, opt=None):
        self.label = label
        self.metric = metric
        self.opt_params = dict()
        self.max_eval = max_eval
        self.opt = opt

    def get_loss(self, y, y_pred):
        if self.metric == 'error':
            return 1 - accuracy_score(y, y_pred)
        elif self.metric == 'precision':
            return 1 - precision_score(y, y_pred)
        elif self.metric == 'recall':
            return 1 - recall_score(y, y_pred)
        elif self.metric == 'macro_f1':
            return 1 - f1_score(y, y_pred, average='macro')
        elif self.metric == 'micro_f1':
            return 1 - f1_score(y, y_pred, average='micro')
        elif self.metric == 'auc':  # TODO: Add a warning checking if y_predict is all [0, 1], it should be probability
            return 1 - roc_auc_score(y, y_pred)
        else:
            raise Exception("Not implemented yet.")

class LGBFitter(FitterBase):
    def __init__(self, label='label', metric='error', opt: LGBOpt = None, max_eval=100):
        super(LGBFitter, self).__init__(label, metric, max_eval)
        if opt is not None:
            self.opt = opt
        else:
            self.opt = LGBOpt()
        self.best_round = None
        self.clf = None

    def train(self, train_df, eval_df, params=None, use_best_eval=True):
        self.best_round = None
        dtrain = lgb.Dataset(train_df.drop(columns=[self.label]), train_df[self.label])
        deval = lgb.Dataset(eval_df.drop(columns=[self.label]), eval_df[self.label])
        evallist = [dtrain, deval]
        if params is None:
            use_params = deepcopy(self.opt_params)
        else:
            use_params = deepcopy(params)

        num_round = use_params.pop('num_round')
        if use_best_eval:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
                output = buf.getvalue().split("\n")
            min_error = np.inf
            min_index = 0
            for idx in range(len(output) - 1):
                if len(output[idx].split("\t")) == 3:
                    temp = float(output[idx].split("\t")[2].split(":")[1])
                    if min_error > temp:
                        min_error = temp
                        min_index = int(output[idx].split("\t")[0][1:-1])
            print("The minimum is attained in round %d" % (min_index + 1))
            self.best_round = min_index + 1
            return output
        else:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
                output = buf.getvalue().split("\n")
            self.best_round = num_round
            return output

    def search(self, train_df, eval_df, use_best_eval=True):
        self.opt_params = dict()

        def train_impl(params):
            self.train(train_df, eval_df, params, use_best_eval)
            if self.metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           num_iteration=self.best_round) > 0.5).astype(int)
            return self.get_loss(eval_df[self.label], y_pred)

        self.opt_params = fmin(train_impl, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def search_k_fold(self, k_fold, data, use_best_eval=True):
        self.opt_params = dict()

        def train_impl_nfold(params):
            loss = list()
            for train_id, eval_id in k_fold.split(data):
                train_df = data.loc[train_id]
                eval_df = data.loc[eval_id]
                self.train(train_df, eval_df, params, use_best_eval)
                if self.metric == 'auc':
                    y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
                else:
                    y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                               num_iteration=self.best_round) > 0.5).astype(int)
                loss.append(self.get_loss(eval_df[self.label], y_pred))
            return np.mean(loss)

        self.opt_params = fmin(train_impl_nfold, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def train_k_fold(self, k_fold, train_data, test_data, params=None, drop_test_y=True, use_best_eval=True):
        acc_result = list()
        train_pred = np.empty(train_data.shape[0])
        test_pred = np.empty(test_data.shape[0])
        if drop_test_y:
            dtest = test_data.drop(columns=self.label)
        else:
            dtest = test_data

        models = list()
        for train_id, eval_id in k_fold.split(train_data):
            train_df = train_data.loc[train_id]
            eval_df = train_data.loc[eval_id]
            self.train(train_df, eval_df, params, use_best_eval)
            models.append(copy.deepcopy(self.clf))
            train_pred[eval_id] = self.clf.predict(eval_df.drop(columns=self.label), num_iteration=self.best_round)
            if self.metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           num_iteration=self.best_round) > 0.5).astype(int)
            acc_result.append(self.get_loss(eval_df[self.label], y_pred))
            test_pred += self.clf.predict(dtest, num_iteration=self.best_round)
        test_pred /= k_fold.n_splits
        return train_pred, test_pred, acc_result, models

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5)

# %% [markdown]
# ### baseline

# %%
fitter = LGBFitter(label='loan_status')

fitter.search_k_fold(kfold, train)
para = space_eval(asdict(fitter.opt), fitter.opt_params)
# Out:
# The minimum is attained in round 737
# The minimum is attained in round 120
# The minimum is attained in round 118
# The minimum is attained in round 164
# The minimum is attained in round 185
# The minimum is attained in round 525
# The minimum is attained in round 146
# The minimum is attained in round 49
# The minimum is attained in round 536
# The minimum is attained in round 140
# The minimum is attained in round 118
# The minimum is attained in round 75
# The minimum is attained in round 557
# The minimum is attained in round 124
# The minimum is attained in round 523
# The minimum is attained in round 125
# The minimum is attained in round 90
# The minimum is attained in round 360
# The minimum is attained in round 126
# The minimum is attained in round 59
# The minimum is attained in round 177
# The minimum is attained in round 237
# The minimum is attained in round 510
# The minimum is attained in round 642
# The minimum is attained in round 788
# The minimum is attained in round 115
# The minimum is attained in round 492
# The minimum is attained in round 416
# The minimum is attained in round 150
# The minimum is attained in round 262
# The minimum is attained in round 644
# The minimum is attained in round 97
# The minimum is attained in round 776
# The minimum is attained in round 715
# 100%|██████████| 100/100 [3:16:57<00:00, 118.17s/trial, best loss: 0.07862]

# %%
fitter = LGBFitter(label='loan_status')
output = fitter.train_k_fold(kfold, train, test, params=para, use_best_eval=True)
test_acc = accuracy_score(test['loan_status'], output[1].round())
print(f'accuracy_score: {test_acc}')
# Out:
# The minimum is attained in round 232
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 252
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 105
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 823
# Finished loading model, total used 1000 iterations
# The minimum is attained in round 163
# Finished loading model, total used 1000 iterations
# accuracy_score: 0.91108

# %%
train_new = train.copy(deep=True)
test_new = test.copy(deep=True)

# %%
# train_new = train_new.drop(columns=['discrete_term_1_one_hot','discrete_home_ownership_1_one_hot',
#                                     'discrete_purpose_1_one_hot','continuous_pub_rec','continuous_dti_joint'])
# test_new = test_new.drop(columns=['discrete_term_1_one_hot','discrete_home_ownership_1_one_hot',
#                                   'discrete_purpose_1_one_hot','continuous_pub_rec','continuous_dti_joint'])

train_new['diff_funded_amt'] = train_new['continuous_funded_amnt'] - train_new['continuous_funded_amnt_inv']
test_new['diff_funded_amt'] = test_new['continuous_funded_amnt'] - test_new['continuous_funded_amnt_inv']

train_new['division_continuous_mths_since'] = train_new['continuous_mths_since_last_record'] / train_new['continuous_mths_since_last_major_derog']
test_new['division_continuous_mths_since'] = test_new['continuous_mths_since_last_record'] / test_new['continuous_mths_since_last_major_derog']

train_new['rate_inst_inc'] = train_new['continuous_installment']*12 / train_new['continuous_annual_inc']
test_new['rate_inst_inc'] = test_new['continuous_installment']*12 / test_new['continuous_annual_inc']

# %%
fitter_new = LGBFitter(label='loan_status')

fitter_new.search_k_fold(kfold, train_new)
para_new = space_eval(asdict(fitter_new.opt), fitter_new.opt_params)
print(para_new)
# Out:
# The minimum is attained in round 231
# The minimum is attained in round 194
# The minimum is attained in round 141
# The minimum is attained in round 365
# The minimum is attained in round 483
# The minimum is attained in round 131
# The minimum is attained in round 852
# The minimum is attained in round 254
# The minimum is attained in round 117
# The minimum is attained in round 160
# The minimum is attained in round 1247
# The minimum is attained in round 106
# The minimum is attained in round 381
# The minimum is attained in round 1200
# The minimum is attained in round 1203
# The minimum is attained in round 564
# The minimum is attained in round 762
# The minimum is attained in round 136
# The minimum is attained in round 366
# The minimum is attained in round 494
# The minimum is attained in round 966
# The minimum is attained in round 193
# The minimum is attained in round 273
# The minimum is attained in round 391
# The minimum is attained in round 265
# The minimum is attained in round 987
# The minimum is attained in round 935
# The minimum is attained in round 1220
# The minimum is attained in round 1445
# The minimum is attained in round 940
# The minimum is attained in round 156
# The minimum is attained in round 296
# The minimum is attained in round 753
# The minimum is attained in round 247
# The minimum is attained in round 407
# The minimum is attained in round 95
# The minimum is attained in round 50
# The minimum is attained in round 216
# The minimum is attained in round 522
# The minimum is attained in round 348
# 100%|██████████| 100/100 [2:14:58<00:00, 80.98s/trial, best loss: 0.07846000000000002]
# {'bagging_fraction': 0.9157939043927217, 'boosting': 'goss', 'device_type': 'cpu', 'drop_rate': 0.015735486188203644, 'extra_trees': True, 'feature_fraction': 0.928029704707654, 'lambda_l1': 1.655536998202204, 'lambda_l2': 5.747973419778714, 'learning_rate': 0.022761363684176618, 'metric': 'binary_error', 'min_gain_to_split': 0.4735214756035615, 'num_leaves': 70, 'num_round': 1500, 'num_threads': 4, 'objective': 'binary', 'uniform_drop': False}

# %%
para_new = {'bagging_fraction': 0.9460815583946198, 'boosting': 'goss', 'device_type': 'cpu', 'drop_rate': 0.19544834548867776, 'extra_trees': True, 'feature_fraction': 0.9808059037360214, 'lambda_l1': 4.582193079266174, 'lambda_l2': 0.8068402557589727, 'learning_rate': 0.0769855835499045, 'metric': 'binary_error', 'min_gain_to_split': 0.9676266908986928, 'num_leaves': 50, 'num_round': 2000, 'num_threads': 4, 'objective': 'binary', 'uniform_drop': True}

# %%
fitter = LGBFitter(label='loan_status')
result = fitter.train_k_fold(kfold, train_new, test_new, params=para_new, use_best_eval=True)
test_acc = accuracy_score(test_new['loan_status'], result[1].round())
print(f'accuracy_score: {test_acc}')
# Out:
# The minimum is attained in round 94
# Finished loading model, total used 1990 iterations
# The minimum is attained in round 147
# Finished loading model, total used 1975 iterations
# The minimum is attained in round 384
# Finished loading model, total used 1973 iterations
# The minimum is attained in round 1521
# Finished loading model, total used 1981 iterations
# The minimum is attained in round 237
# Finished loading model, total used 1984 iterations
# accuracy_score: 0.91822

# %% [markdown]
# ## xgboost

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %%
dtrain = xgb.DMatrix(train.drop(columns='loan_status'), label=train['loan_status'])
dtest = xgb.DMatrix(test.drop(columns='loan_status'), label=test['loan_status'])

# %%
param = {'max_depth': 10, 'eta': 0.02, 'gamma': 1, 'objective': 'binary:logistic', 'eval_metric': ["error"],'nthread':4,}

num_round = 300
evallist = [(dtest, 'eval'), (dtrain, 'train')]
bst = xgb.train(param, dtrain, num_round, evallist)
# Out:
# [0]	eval-error:0.09322	train-error:0.06544
# [1]	eval-error:0.09206	train-error:0.06484
# [2]	eval-error:0.09132	train-error:0.06346
# [3]	eval-error:0.09100	train-error:0.06328
# [4]	eval-error:0.08976	train-error:0.06324
# [5]	eval-error:0.09022	train-error:0.06284
# [6]	eval-error:0.08970	train-error:0.06258
# [7]	eval-error:0.08896	train-error:0.06266
# [8]	eval-error:0.08918	train-error:0.06108
# [9]	eval-error:0.08878	train-error:0.06154
# [10]	eval-error:0.08878	train-error:0.06066
# [11]	eval-error:0.08850	train-error:0.06096
# [12]	eval-error:0.08842	train-error:0.06076
# [13]	eval-error:0.08816	train-error:0.06062
# [14]	eval-error:0.08822	train-error:0.06050
# [15]	eval-error:0.08830	train-error:0.06048
# [16]	eval-error:0.08822	train-error:0.06012
# [17]	eval-error:0.08798	train-error:0.05988
# [18]	eval-error:0.08800	train-error:0.05944
# [19]	eval-error:0.08786	train-error:0.05926
# [20]	eval-error:0.08748	train-error:0.05904
# [21]	eval-error:0.08738	train-error:0.05896
# [22]	eval-error:0.08734	train-error:0.05878
# [23]	eval-error:0.08720	train-error:0.05866
# [24]	eval-error:0.08680	train-error:0.05840
# [25]	eval-error:0.08684	train-error:0.05854
# [26]	eval-error:0.08656	train-error:0.05828
# [27]	eval-error:0.08656	train-error:0.05782
# [28]	eval-error:0.08622	train-error:0.05784
# [29]	eval-error:0.08632	train-error:0.05784
# [30]	eval-error:0.08640	train-error:0.05770
# [31]	eval-error:0.08612	train-error:0.05758
# [32]	eval-error:0.08628	train-error:0.05766
# [33]	eval-error:0.08604	train-error:0.05756
# [34]	eval-error:0.08606	train-error:0.05750
# [35]	eval-error:0.08588	train-error:0.05732
# [36]	eval-error:0.08578	train-error:0.05740
# [37]	eval-error:0.08582	train-error:0.05688
# [38]	eval-error:0.08564	train-error:0.05676
# [39]	eval-error:0.08568	train-error:0.05670
# [40]	eval-error:0.08574	train-error:0.05662
# [41]	eval-error:0.08554	train-error:0.05676
# [42]	eval-error:0.08554	train-error:0.05670
# [43]	eval-error:0.08528	train-error:0.05664
# [44]	eval-error:0.08512	train-error:0.05666
# [45]	eval-error:0.08520	train-error:0.05662
# [46]	eval-error:0.08498	train-error:0.05654
# [47]	eval-error:0.08494	train-error:0.05668
# [48]	eval-error:0.08482	train-error:0.05640
# [49]	eval-error:0.08486	train-error:0.05632
# [50]	eval-error:0.08486	train-error:0.05626
# [51]	eval-error:0.08480	train-error:0.05620
# [52]	eval-error:0.08496	train-error:0.05618
# [53]	eval-error:0.08500	train-error:0.05602
# [54]	eval-error:0.08494	train-error:0.05582
# [55]	eval-error:0.08500	train-error:0.05576
# [56]	eval-error:0.08486	train-error:0.05554
# [57]	eval-error:0.08480	train-error:0.05546
# [58]	eval-error:0.08482	train-error:0.05542
# [59]	eval-error:0.08474	train-error:0.05522
# [60]	eval-error:0.08478	train-error:0.05518
# [61]	eval-error:0.08482	train-error:0.05512
# [62]	eval-error:0.08488	train-error:0.05502
# [63]	eval-error:0.08496	train-error:0.05482
# [64]	eval-error:0.08482	train-error:0.05474
# [65]	eval-error:0.08498	train-error:0.05466
# [66]	eval-error:0.08492	train-error:0.05440
# [67]	eval-error:0.08508	train-error:0.05426
# [68]	eval-error:0.08508	train-error:0.05414
# [69]	eval-error:0.08520	train-error:0.05402
# [70]	eval-error:0.08528	train-error:0.05388
# [71]	eval-error:0.08526	train-error:0.05380
# [72]	eval-error:0.08528	train-error:0.05368
# [73]	eval-error:0.08522	train-error:0.05350
# [74]	eval-error:0.08524	train-error:0.05370
# [75]	eval-error:0.08530	train-error:0.05358
# [76]	eval-error:0.08526	train-error:0.05360
# [77]	eval-error:0.08522	train-error:0.05350
# [78]	eval-error:0.08506	train-error:0.05330
# [79]	eval-error:0.08522	train-error:0.05328
# [80]	eval-error:0.08514	train-error:0.05318
# [81]	eval-error:0.08502	train-error:0.05296
# [82]	eval-error:0.08508	train-error:0.05300
# [83]	eval-error:0.08498	train-error:0.05296
# [84]	eval-error:0.08498	train-error:0.05298
# [85]	eval-error:0.08508	train-error:0.05288
# [86]	eval-error:0.08490	train-error:0.05274
# [87]	eval-error:0.08482	train-error:0.05270
# [88]	eval-error:0.08472	train-error:0.05266
# [89]	eval-error:0.08472	train-error:0.05268
# [90]	eval-error:0.08480	train-error:0.05254
# [91]	eval-error:0.08480	train-error:0.05244
# [92]	eval-error:0.08474	train-error:0.05248
# [93]	eval-error:0.08476	train-error:0.05236
# [94]	eval-error:0.08496	train-error:0.05236
# [95]	eval-error:0.08496	train-error:0.05230
# [96]	eval-error:0.08490	train-error:0.05222
# [97]	eval-error:0.08484	train-error:0.05220
# [98]	eval-error:0.08490	train-error:0.05212
# [99]	eval-error:0.08488	train-error:0.05204
# [100]	eval-error:0.08486	train-error:0.05200
# [101]	eval-error:0.08480	train-error:0.05206
# [102]	eval-error:0.08482	train-error:0.05204
# [103]	eval-error:0.08474	train-error:0.05194
# [104]	eval-error:0.08468	train-error:0.05202
# [105]	eval-error:0.08472	train-error:0.05184
# [106]	eval-error:0.08474	train-error:0.05186
# [107]	eval-error:0.08462	train-error:0.05184
# [108]	eval-error:0.08448	train-error:0.05178
# [109]	eval-error:0.08450	train-error:0.05170
# [110]	eval-error:0.08446	train-error:0.05164
# [111]	eval-error:0.08450	train-error:0.05160
# [112]	eval-error:0.08444	train-error:0.05164
# [113]	eval-error:0.08448	train-error:0.05162
# [114]	eval-error:0.08456	train-error:0.05142
# [115]	eval-error:0.08442	train-error:0.05136
# [116]	eval-error:0.08452	train-error:0.05132
# [117]	eval-error:0.08442	train-error:0.05132
# [118]	eval-error:0.08446	train-error:0.05114
# [119]	eval-error:0.08440	train-error:0.05108
# [120]	eval-error:0.08446	train-error:0.05102
# [121]	eval-error:0.08446	train-error:0.05088
# [122]	eval-error:0.08446	train-error:0.05082
# [123]	eval-error:0.08436	train-error:0.05080
# [124]	eval-error:0.08446	train-error:0.05078
# [125]	eval-error:0.08448	train-error:0.05070
# [126]	eval-error:0.08448	train-error:0.05062
# [127]	eval-error:0.08446	train-error:0.05068
# [128]	eval-error:0.08454	train-error:0.05062
# [129]	eval-error:0.08454	train-error:0.05048
# [130]	eval-error:0.08460	train-error:0.05046
# [131]	eval-error:0.08468	train-error:0.05034
# [132]	eval-error:0.08472	train-error:0.05040
# [133]	eval-error:0.08466	train-error:0.05028
# [134]	eval-error:0.08464	train-error:0.05026
# [135]	eval-error:0.08462	train-error:0.05020
# [136]	eval-error:0.08462	train-error:0.05024
# [137]	eval-error:0.08460	train-error:0.05022
# [138]	eval-error:0.08458	train-error:0.05020
# [139]	eval-error:0.08464	train-error:0.05016
# [140]	eval-error:0.08478	train-error:0.05016
# [141]	eval-error:0.08472	train-error:0.05010
# [142]	eval-error:0.08474	train-error:0.05010
# [143]	eval-error:0.08462	train-error:0.05004
# [144]	eval-error:0.08454	train-error:0.05002
# [145]	eval-error:0.08456	train-error:0.04990
# [146]	eval-error:0.08462	train-error:0.04974
# [147]	eval-error:0.08468	train-error:0.04970
# [148]	eval-error:0.08464	train-error:0.04972
# [149]	eval-error:0.08468	train-error:0.04972
# [150]	eval-error:0.08478	train-error:0.04968
# [151]	eval-error:0.08474	train-error:0.04962
# [152]	eval-error:0.08472	train-error:0.04956
# [153]	eval-error:0.08472	train-error:0.04952
# [154]	eval-error:0.08466	train-error:0.04954
# [155]	eval-error:0.08464	train-error:0.04942
# [156]	eval-error:0.08458	train-error:0.04936
# [157]	eval-error:0.08464	train-error:0.04930
# [158]	eval-error:0.08468	train-error:0.04912
# [159]	eval-error:0.08470	train-error:0.04918
# [160]	eval-error:0.08460	train-error:0.04910
# [161]	eval-error:0.08464	train-error:0.04900
# [162]	eval-error:0.08462	train-error:0.04900
# [163]	eval-error:0.08468	train-error:0.04886
# [164]	eval-error:0.08470	train-error:0.04876
# [165]	eval-error:0.08466	train-error:0.04868
# [166]	eval-error:0.08458	train-error:0.04852
# [167]	eval-error:0.08458	train-error:0.04850
# [168]	eval-error:0.08462	train-error:0.04846
# [169]	eval-error:0.08466	train-error:0.04844
# [170]	eval-error:0.08468	train-error:0.04842
# [171]	eval-error:0.08464	train-error:0.04840
# [172]	eval-error:0.08458	train-error:0.04842
# [173]	eval-error:0.08454	train-error:0.04844
# [174]	eval-error:0.08458	train-error:0.04828
# [175]	eval-error:0.08460	train-error:0.04810
# [176]	eval-error:0.08464	train-error:0.04814
# [177]	eval-error:0.08476	train-error:0.04810
# [178]	eval-error:0.08466	train-error:0.04808
# [179]	eval-error:0.08464	train-error:0.04808
# [180]	eval-error:0.08466	train-error:0.04812
# [181]	eval-error:0.08464	train-error:0.04810
# [182]	eval-error:0.08464	train-error:0.04810
# [183]	eval-error:0.08464	train-error:0.04794
# [184]	eval-error:0.08464	train-error:0.04790
# [185]	eval-error:0.08466	train-error:0.04784
# [186]	eval-error:0.08470	train-error:0.04778
# [187]	eval-error:0.08462	train-error:0.04778
# [188]	eval-error:0.08466	train-error:0.04768
# [189]	eval-error:0.08462	train-error:0.04764
# [190]	eval-error:0.08458	train-error:0.04760
# [191]	eval-error:0.08460	train-error:0.04758
# [192]	eval-error:0.08462	train-error:0.04754
# [193]	eval-error:0.08458	train-error:0.04748
# [194]	eval-error:0.08460	train-error:0.04734
# [195]	eval-error:0.08458	train-error:0.04728
# [196]	eval-error:0.08460	train-error:0.04728
# [197]	eval-error:0.08458	train-error:0.04732
# [198]	eval-error:0.08466	train-error:0.04720
# [199]	eval-error:0.08456	train-error:0.04714
# [200]	eval-error:0.08460	train-error:0.04710
# [201]	eval-error:0.08462	train-error:0.04708
# [202]	eval-error:0.08460	train-error:0.04700
# [203]	eval-error:0.08452	train-error:0.04702
# [204]	eval-error:0.08458	train-error:0.04704
# [205]	eval-error:0.08466	train-error:0.04700
# [206]	eval-error:0.08470	train-error:0.04694
# [207]	eval-error:0.08468	train-error:0.04684
# [208]	eval-error:0.08464	train-error:0.04682
# [209]	eval-error:0.08460	train-error:0.04672
# [210]	eval-error:0.08464	train-error:0.04670
# [211]	eval-error:0.08464	train-error:0.04662
# [212]	eval-error:0.08460	train-error:0.04656
# [213]	eval-error:0.08464	train-error:0.04658
# [214]	eval-error:0.08462	train-error:0.04656
# [215]	eval-error:0.08458	train-error:0.04650
# [216]	eval-error:0.08462	train-error:0.04642
# [217]	eval-error:0.08456	train-error:0.04640
# [218]	eval-error:0.08462	train-error:0.04630
# [219]	eval-error:0.08456	train-error:0.04624
# [220]	eval-error:0.08456	train-error:0.04626
# [221]	eval-error:0.08460	train-error:0.04618
# [222]	eval-error:0.08462	train-error:0.04620
# [223]	eval-error:0.08466	train-error:0.04608
# [224]	eval-error:0.08468	train-error:0.04612
# [225]	eval-error:0.08468	train-error:0.04604
# [226]	eval-error:0.08466	train-error:0.04600
# [227]	eval-error:0.08470	train-error:0.04598
# [228]	eval-error:0.08474	train-error:0.04600
# [229]	eval-error:0.08462	train-error:0.04598
# [230]	eval-error:0.08460	train-error:0.04588
# [231]	eval-error:0.08452	train-error:0.04588
# [232]	eval-error:0.08454	train-error:0.04580
# [233]	eval-error:0.08448	train-error:0.04574
# [234]	eval-error:0.08450	train-error:0.04574
# [235]	eval-error:0.08454	train-error:0.04566
# [236]	eval-error:0.08454	train-error:0.04564
# [237]	eval-error:0.08452	train-error:0.04560
# [238]	eval-error:0.08452	train-error:0.04560
# [239]	eval-error:0.08458	train-error:0.04556
# [240]	eval-error:0.08456	train-error:0.04546
# [241]	eval-error:0.08460	train-error:0.04540
# [242]	eval-error:0.08458	train-error:0.04532
# [243]	eval-error:0.08452	train-error:0.04536
# [244]	eval-error:0.08456	train-error:0.04536
# [245]	eval-error:0.08452	train-error:0.04536
# [246]	eval-error:0.08456	train-error:0.04530
# [247]	eval-error:0.08452	train-error:0.04522
# [248]	eval-error:0.08448	train-error:0.04522
# [249]	eval-error:0.08446	train-error:0.04522
# [250]	eval-error:0.08440	train-error:0.04518
# [251]	eval-error:0.08446	train-error:0.04516
# [252]	eval-error:0.08444	train-error:0.04514
# [253]	eval-error:0.08446	train-error:0.04508
# [254]	eval-error:0.08444	train-error:0.04500
# [255]	eval-error:0.08448	train-error:0.04496
# [256]	eval-error:0.08448	train-error:0.04484
# [257]	eval-error:0.08450	train-error:0.04484
# [258]	eval-error:0.08450	train-error:0.04478
# [259]	eval-error:0.08454	train-error:0.04474
# [260]	eval-error:0.08454	train-error:0.04472
# [261]	eval-error:0.08452	train-error:0.04474
# [262]	eval-error:0.08448	train-error:0.04466
# [263]	eval-error:0.08448	train-error:0.04462
# [264]	eval-error:0.08454	train-error:0.04458
# [265]	eval-error:0.08454	train-error:0.04458
# [266]	eval-error:0.08454	train-error:0.04456
# [267]	eval-error:0.08440	train-error:0.04458
# [268]	eval-error:0.08450	train-error:0.04452
# [269]	eval-error:0.08452	train-error:0.04448
# [270]	eval-error:0.08448	train-error:0.04440
# [271]	eval-error:0.08448	train-error:0.04442
# [272]	eval-error:0.08444	train-error:0.04438
# [273]	eval-error:0.08446	train-error:0.04436
# [274]	eval-error:0.08446	train-error:0.04432
# [275]	eval-error:0.08446	train-error:0.04428
# [276]	eval-error:0.08444	train-error:0.04432
# [277]	eval-error:0.08448	train-error:0.04430
# [278]	eval-error:0.08442	train-error:0.04426
# [279]	eval-error:0.08446	train-error:0.04414
# [280]	eval-error:0.08444	train-error:0.04404
# [281]	eval-error:0.08442	train-error:0.04400
# [282]	eval-error:0.08450	train-error:0.04396
# [283]	eval-error:0.08442	train-error:0.04382
# [284]	eval-error:0.08442	train-error:0.04380
# [285]	eval-error:0.08448	train-error:0.04374
# [286]	eval-error:0.08448	train-error:0.04364
# [287]	eval-error:0.08446	train-error:0.04354
# [288]	eval-error:0.08442	train-error:0.04354
# [289]	eval-error:0.08440	train-error:0.04354
# [290]	eval-error:0.08436	train-error:0.04356
# [291]	eval-error:0.08432	train-error:0.04350
# [292]	eval-error:0.08438	train-error:0.04338
# [293]	eval-error:0.08444	train-error:0.04338
# [294]	eval-error:0.08436	train-error:0.04324
# [295]	eval-error:0.08434	train-error:0.04314
# [296]	eval-error:0.08434	train-error:0.04310
# [297]	eval-error:0.08434	train-error:0.04302
# [298]	eval-error:0.08432	train-error:0.04304
# [299]	eval-error:0.08434	train-error:0.04300

# %%
ypred = bst.predict(dtest)
print('acc:', accuracy_score(test['loan_status'], ypred.round()))
# Out:
# acc: 0.91574

# %%
cpu_count = 4
use_gpu = False
@dataclass
class XGBOpt:
    nthread: any = hp.choice('nthread', [cpu_count])
    max_depth: any = hp.choice('max_depth', range(3,12,2))
    eval_metric: any = hp.choice('eval_metric', ['error'])
    num_round: any = hp.choice('num_round', [800])
    objective: any = hp.choice('objective', ['binary:logistic'])
    eta: any = hp.uniform('eta', 0.04, 0.8)
    gamma: any = hp.uniform('gamma', 0.3, 0.9)
        
    booster: any = hp.choice('booster', ['gbtree', 'dart', 'gblinear'])
    sampling_method: any = hp.choice('sampling_method', ['uniform', 'gradient_based'])
#     reg_lambda: any = hp.uniform('reg_lambda', 0, 10)
#     reg_alpha: any = hp.uniform('reg_alpha', 0, 10)
    tree_method: any = hp.choice('tree_method', ['exact', 'approx', 'hist'])

# %%
class FitterBase(object):
    def __init__(self, label, metric, max_eval=100, opt=None):
        self.label = label
        self.eval_metric = metric
        self.opt_params = dict()
        self.max_eval = max_eval
        self.opt = opt

    def get_loss(self, y, y_pred):
        if self.eval_metric == 'error':
            return 1 - accuracy_score(y, y_pred)
        elif self.eval_metric == 'precision':
            return 1 - precision_score(y, y_pred)
        elif self.eval_metric == 'recall':
            return 1 - recall_score(y, y_pred)
        elif self.eval_metric == 'macro_f1':
            return 1 - f1_score(y, y_pred, average='macro')
        elif self.eval_metric == 'micro_f1':
            return 1 - f1_score(y, y_pred, average='micro')
        elif self.eval_metric == 'auc':  # TODO: Add a warning checking if y_predict is all [0, 1], it should be probability
            return 1 - roc_auc_score(y, y_pred)
        else:
            raise Exception("Not implemented yet.")

class XGBFitter(FitterBase):
    def __init__(self, label='label', eval_metric='error', opt: XGBOpt = None, max_eval=100):
        super(XGBFitter, self).__init__(label, eval_metric, max_eval)
        if opt is not None:
            self.opt = opt
        else:
            self.opt = XGBOpt()
        self.best_round = None
        self.clf = None

    def train(self, train_df, eval_df, params=None, use_best_eval=True):
        self.best_round = None
        dtrain = xgb.DMatrix(train_df.drop(columns=[self.label]), train_df[self.label])
        deval = xgb.DMatrix(eval_df.drop(columns=[self.label]), eval_df[self.label])
        evallist = [(deval, 'eval'), (dtrain, 'train')]
        if params is None:
            use_params = deepcopy(self.opt_params)
        else:
            use_params = deepcopy(params)

        num_round = use_params.pop('num_round')
        if use_best_eval:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = xgb.train(use_params, dtrain, num_round, evallist)
                output = buf.getvalue().split("\n")
            min_error = np.inf
            min_index = 0
            for idx in range(len(output) - 1):
                if len(output[idx].split("\t")) == 3:
                    temp = float(output[idx].split("\t")[2].split(":")[1])
                    if min_error > temp:
                        min_error = temp
                        min_index = int(output[idx].split("\t")[0][1:-1])
            print("The minimum is attained in round %d" % (min_index + 1))
            self.best_round = min_index + 1
            return output
        else:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, evallist)
                output = buf.getvalue().split("\n")
            self.best_round = num_round
            return output

    def search(self, train_df, eval_df, use_best_eval=True):
        self.opt_params = dict()

        def train_impl(params):
            self.train(train_df, eval_df, params, use_best_eval)
            if self.eval_metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), early_stopping_rounds=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           early_stopping_rounds=self.best_round) > 0.5).astype(int)
            return self.get_loss(eval_df[self.label], y_pred)

        self.opt_params = fmin(train_impl, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def search_k_fold(self, k_fold, data, use_best_eval=True):
        self.opt_params = dict()

        def train_impl_nfold(params):
            loss = list()
            for train_id, eval_id in k_fold.split(data):
                train_df = data.loc[train_id]
                eval_df = data.loc[eval_id]
                dtrain = xgb.DMatrix(train_df.drop(columns=[self.label]), train_df[self.label])
                deval = xgb.DMatrix(eval_df.drop(columns=[self.label]), eval_df[self.label])
                self.train(train_df, eval_df, params, use_best_eval)
                if self.eval_metric == 'auc':
                    y_pred = self.clf.predict(eval_df.drop(columns=[self.label]))
                else:
                    y_pred = (self.clf.predict(deval) > 0.5).astype(int)
                loss.append(self.get_loss(eval_df[self.label], y_pred))
            return np.mean(loss)
        self.opt_params = fmin(train_impl_nfold, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def train_k_fold(self, k_fold, train_data, test_data, params=None, drop_test_y=True, use_best_eval=True):
        acc_result = list()
        train_pred = np.empty(train_data.shape[0])
        test_pred = np.empty(test_data.shape[0])
        if drop_test_y:
            dtest = test_data.drop(columns=self.label)
        else:
            dtest = test_data

        models = list()
        for train_id, eval_id in k_fold.split(train_data):
            train_df = train_data.loc[train_id]
            eval_df = train_data.loc[eval_id]
            self.train(train_df, eval_df, params, use_best_eval)
            models.append(copy.deepcopy(self.clf))
            train_pred[eval_id] = self.clf.predict(eval_df.drop(columns=self.label), early_stopping_rounds=self.best_round)
            if self.eval_metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), early_stopping_rounds=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           early_stopping_rounds=self.best_round) > 0.5).astype(int)
            acc_result.append(self.get_loss(eval_df[self.label], y_pred))
            test_pred += self.clf.predict(dtest, early_stopping_rounds=self.best_round)
        test_pred /= k_fold.n_splits
        return train_pred, test_pred, acc_result, models

# %%
fitter = XGBFitter(label='loan_status')
result = fitter.train_k_fold(kfold, train, test, params=param, use_best_eval=True)
test_acc = accuracy_score(test_new['loan_status'], result[1].round())
print(f'accuracy_score: {test_acc}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-794b9151415b> in <module>
#       1 fitter = XGBFitter(label='loan_status')
# ----> 2 result = fitter.train_k_fold(kfold, train, test, params=param, use_best_eval=True)
#       3 test_acc = accuracy_score(test_new['loan_status'], result[1].round())
#       4 print(f'accuracy_score: {test_acc}')
#
# <ipython-input-156-19fce29be3f5> in train_k_fold(self, k_fold, train_data, test_data, params, drop_test_y, use_best_eval)
#     112             train_df = train_data.loc[train_id]
#     113             eval_df = train_data.loc[eval_id]
# --> 114             self.train(train_df, eval_df, params, use_best_eval)
#     115             models.append(copy.deepcopy(self.clf))
#     116             train_pred[eval_id] = self.clf.predict(eval_df.drop(columns=self.label), early_stopping_rounds=self.best_round)
#
# <ipython-input-156-19fce29be3f5> in train(self, train_df, eval_df, params, use_best_eval)
#      43             use_params = deepcopy(params)
#      44
# ---> 45         num_round = use_params.pop('num_round')
#      46         if use_best_eval:
#      47             with io.StringIO() as buf, redirect_stdout(buf):
#
# KeyError: 'num_round'

# %% [markdown]
# ## randomForest

# %%
class RFOpt:
    num_threads: any = hp.choice('num_threads', [cpu_count])
    num_leaves: any = hp.choice('num_leaves', [100,150,200,250,300])
    metric: any = hp.choice('metric', ['binary_error'])
    num_round: any = hp.choice('num_rounds', [1000])
    objective: any = hp.choice('objective', ['binary'])
    learning_rate: any = hp.uniform('learning_rate', 0.01, 0.1)
    feature_fraction: any = hp.uniform('feature_fraction', 0.5, 1.0)
    bagging_fraction: any = hp.uniform('bagging_fraction', 0.4, 1.0)
    device_type: any = hp.choice('device_tpye', ['gpu']) if use_gpu else hp.choice('device_type',
                                                                                   ['cpu'])
    boosting: any = hp.choice('boosting', ['rf'])
    extra_trees: any = hp.choice('extra_tress', [False, True])
    drop_rate: any = hp.uniform('drop_rate', 0, 0.2)
    uniform_drop: any = hp.choice('uniform_drop', [True, False])
    lambda_l1: any = hp.uniform('lambda_l1', 0, 10)  # TODO: Check range
    lambda_l2: any = hp.uniform('lambda_l2', 0, 10)  # TODO: Check range
    min_gain_to_split: any = hp.uniform('min_gain_to_split', 0, 1)  # TODO: Check range
    min_data_in_bin = hp.choice('min_data_in_bin', [3, 5, 10, 15, 20, 50])

    @staticmethod
    def get_common_params():
        return {'num_thread': 4, 'num_leaves': 12, 'metric': 'binary', 'objective': 'binary',
                'num_round': 1000, 'learning_rate': 0.01, 'feature_fraction': 0.8, 'bagging_fraction': 0.8}

# %%
class FitterBase(object):
    def __init__(self, label, metric, max_eval=100, opt=None):
        self.label = label
        self.metric = metric
        self.opt_params = dict()
        self.max_eval = max_eval
        self.opt = opt

    def get_loss(self, y, y_pred):
        if self.metric == 'error':
            return 1 - accuracy_score(y, y_pred)
        elif self.metric == 'precision':
            return 1 - precision_score(y, y_pred)
        elif self.metric == 'recall':
            return 1 - recall_score(y, y_pred)
        elif self.metric == 'macro_f1':
            return 1 - f1_score(y, y_pred, average='macro')
        elif self.metric == 'micro_f1':
            return 1 - f1_score(y, y_pred, average='micro')
        elif self.metric == 'auc':  # TODO: Add a warning checking if y_predict is all [0, 1], it should be probability
            return 1 - roc_auc_score(y, y_pred)
        else:
            raise Exception("Not implemented yet.")

class RFFitter(FitterBase):
    def __init__(self, label='label', metric='error', opt: LGBOpt = None, max_eval=100):
        super(RFFitter, self).__init__(label, metric, max_eval)
        if opt is not None:
            self.opt = opt
        else:
            self.opt = LGBOpt()
        self.best_round = None
        self.clf = None

    def train(self, train_df, eval_df, params=None, use_best_eval=True):
        self.best_round = None
        dtrain = lgb.Dataset(train_df.drop(columns=[self.label]), train_df[self.label])
        deval = lgb.Dataset(eval_df.drop(columns=[self.label]), eval_df[self.label])
        evallist = [dtrain, deval]
        if params is None:
            use_params = deepcopy(self.opt_params)
        else:
            use_params = deepcopy(params)

        num_round = use_params.pop('num_round')
        if use_best_eval:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
                output = buf.getvalue().split("\n")
            min_error = np.inf
            min_index = 0
            for idx in range(len(output) - 1):
                if len(output[idx].split("\t")) == 3:
                    temp = float(output[idx].split("\t")[2].split(":")[1])
                    if min_error > temp:
                        min_error = temp
                        min_index = int(output[idx].split("\t")[0][1:-1])
            print("The minimum is attained in round %d" % (min_index + 1))
            self.best_round = min_index + 1
            return output
        else:
            with io.StringIO() as buf, redirect_stdout(buf):
                self.clf = lgb.train(use_params, dtrain, num_round, valid_sets=evallist)
                output = buf.getvalue().split("\n")
            self.best_round = num_round
            return output

    def search(self, train_df, eval_df, use_best_eval=True):
        self.opt_params = dict()

        def train_impl(params):
            self.train(train_df, eval_df, params, use_best_eval)
            if self.metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           num_iteration=self.best_round) > 0.5).astype(int)
            return self.get_loss(eval_df[self.label], y_pred)

        self.opt_params = fmin(train_impl, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def search_k_fold(self, k_fold, data, use_best_eval=True):
        self.opt_params = dict()

        def train_impl_nfold(params):
            loss = list()
            for train_id, eval_id in k_fold.split(data):
                train_df = data.loc[train_id]
                eval_df = data.loc[eval_id]
                self.train(train_df, eval_df, params, use_best_eval)
                if self.metric == 'auc':
                    y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
                else:
                    y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                               num_iteration=self.best_round) > 0.5).astype(int)
                loss.append(self.get_loss(eval_df[self.label], y_pred))
            return np.mean(loss)

        self.opt_params = fmin(train_impl_nfold, asdict(self.opt), algo=tpe.suggest, max_evals=self.max_eval)

    def train_k_fold(self, k_fold, train_data, test_data, params=None, drop_test_y=True, use_best_eval=True):
        acc_result = list()
        train_pred = np.empty(train_data.shape[0])
        test_pred = np.empty(test_data.shape[0])
        if drop_test_y:
            dtest = test_data.drop(columns=self.label)
        else:
            dtest = test_data

        models = list()
        for train_id, eval_id in k_fold.split(train_data):
            train_df = train_data.loc[train_id]
            eval_df = train_data.loc[eval_id]
            self.train(train_df, eval_df, params, use_best_eval)
            models.append(copy.deepcopy(self.clf))
            train_pred[eval_id] = self.clf.predict(eval_df.drop(columns=self.label), num_iteration=self.best_round)
            if self.metric == 'auc':
                y_pred = self.clf.predict(eval_df.drop(columns=[self.label]), num_iteration=self.best_round)
            else:
                y_pred = (self.clf.predict(eval_df.drop(columns=[self.label]),
                                           num_iteration=self.best_round) > 0.5).astype(int)
            acc_result.append(self.get_loss(eval_df[self.label], y_pred))
            test_pred += self.clf.predict(dtest, num_iteration=self.best_round)
        test_pred /= k_fold.n_splits
        return train_pred, test_pred, acc_result, models

# %%
fitter_new ==RFFitter(label='loan_status')

fitter_new.search_k_fold(kfold, train_new)
para_new = space_eval(asdict(fitter_new.opt), fitter_new.opt_params)
print(para_new)
# Out:
# The minimum is attained in round 118
# The minimum is attained in round 68
# The minimum is attained in round 241
# The minimum is attained in round 965
# The minimum is attained in round 1017
# The minimum is attained in round 83
# The minimum is attained in round 101
# The minimum is attained in round 122
# The minimum is attained in round 248
# The minimum is attained in round 94
# The minimum is attained in round 1484
# The minimum is attained in round 544
# The minimum is attained in round 974
# The minimum is attained in round 1319
# The minimum is attained in round 750
# The minimum is attained in round 136
# The minimum is attained in round 62
# The minimum is attained in round 87
# The minimum is attained in round 98
# The minimum is attained in round 149
# The minimum is attained in round 519
# The minimum is attained in round 1493
# The minimum is attained in round 1477
# The minimum is attained in round 649
# The minimum is attained in round 304
# The minimum is attained in round 71
# The minimum is attained in round 38
# The minimum is attained in round 38
# The minimum is attained in round 137
# The minimum is attained in round 86
# The minimum is attained in round 80
# The minimum is attained in round 86
# The minimum is attained in round 1319
# The minimum is attained in round 253
# The minimum is attained in round 184
# The minimum is attained in round 218
# The minimum is attained in round 273
# The minimum is attained in round 457
# The minimum is attained in round 861
# The minimum is attained in round 502
# The minimum is attained in round 138
# The minimum is attained in round 192
# The minimum is attained in round 163
# The minimum is attained in round 305
# The minimum is attained in round 260
# The minimum is attained in round 217
# The minimum is attained in round 965
# The minimum is attained in round 337
# The minimum is attained in round 1432
# The minimum is attained in round 121
# The minimum is attained in round 59
# The minimum is attained in round 55
# The minimum is attained in round 37
# The minimum is attained in round 1331
# The minimum is attained in round 111
# The minimum is attained in round 107
# The minimum is attained in round 71
# The minimum is attained in round 53
# The minimum is attained in round 362
# The minimum is attained in round 259
# The minimum is attained in round 243
# The minimum is attained in round 178
# The minimum is attained in round 213
# The minimum is attained in round 501
# The minimum is attained in round 767
# The minimum is attained in round 207
# The minimum is attained in round 96
# The minimum is attained in round 71
# The minimum is attained in round 268
# The minimum is attained in round 308
# The minimum is attained in round 812
# The minimum is attained in round 1183
# The minimum is attained in round 662
# The minimum is attained in round 99
# The minimum is attained in round 155
# The minimum is attained in round 183
# The minimum is attained in round 119
# The minimum is attained in round 171
# The minimum is attained in round 1153
# The minimum is attained in round 300
# The minimum is attained in round 100
# The minimum is attained in round 57
# The minimum is attained in round 1016
# The minimum is attained in round 588
# The minimum is attained in round 77
# The minimum is attained in round 108
# The minimum is attained in round 214
# The minimum is attained in round 130
# The minimum is attained in round 1148
# The minimum is attained in round 218
# The minimum is attained in round 124
# The minimum is attained in round 114
# The minimum is attained in round 1218
# The minimum is attained in round 1227
# The minimum is attained in round 1081
# The minimum is attained in round 753
# The minimum is attained in round 131
# The minimum is attained in round 245
# The minimum is attained in round 765
# The minimum is attained in round 402
# The minimum is attained in round 154
# The minimum is attained in round 323
# The minimum is attained in round 431
# The minimum is attained in round 614
# The minimum is attained in round 641
# The minimum is attained in round 143
# The minimum is attained in round 97
# The minimum is attained in round 358
# The minimum is attained in round 1212
# The minimum is attained in round 497
# The minimum is attained in round 62
# The minimum is attained in round 299
# The minimum is attained in round 332
# The minimum is attained in round 979
# The minimum is attained in round 76
# The minimum is attained in round 167
# The minimum is attained in round 79
# The minimum is attained in round 45
# The minimum is attained in round 504
# The minimum is attained in round 370
# The minimum is attained in round 96
# The minimum is attained in round 490
# The minimum is attained in round 592
# The minimum is attained in round 232
# The minimum is attained in round 768
# The minimum is attained in round 167
# The minimum is attained in round 90
# The minimum is attained in round 144
# The minimum is attained in round 362
# The minimum is attained in round 203
# The minimum is attained in round 360
# The minimum is attained in round 1116
# The minimum is attained in round 1447
# The minimum is attained in round 729
# The minimum is attained in round 302
# The minimum is attained in round 170
# The minimum is attained in round 76
# The minimum is attained in round 85
# The minimum is attained in round 298
# The minimum is attained in round 238
# The minimum is attained in round 136
# The minimum is attained in round 107
# The minimum is attained in round 183
# The minimum is attained in round 1346
# The minimum is attained in round 1296
# The minimum is attained in round 184
# The minimum is attained in round 907
# The minimum is attained in round 336
# The minimum is attained in round 820
# The minimum is attained in round 239
# The minimum is attained in round 128
# The minimum is attained in round 133
# The minimum is attained in round 48
# The minimum is attained in round 438
# The minimum is attained in round 185
# 100%|██████████| 100/100 [2:02:29<00:00, 73.49s/trial, best loss: 0.07884]
# {'bagging_fraction': 0.8622628175801537, 'boosting': 'gbdt', 'device_type': 'cpu', 'drop_rate': 0.012189396685657418, 'extra_trees': True, 'feature_fraction': 0.9550505045944456, 'lambda_l1': 8.640405964119157, 'lambda_l2': 6.050795522543783, 'learning_rate': 0.04072548365409167, 'metric': 'binary_error', 'min_gain_to_split': 0.047085255255949865, 'num_leaves': 80, 'num_round': 1500, 'num_threads': 4, 'objective': 'binary', 'uniform_drop': False}

# %%
fitter_new ==RFFitter(label='loan_status')

fitter_new.search_k_fold(kfold, train_new)
para_new = space_eval(asdict(fitter_new.opt), fitter_new.opt_params)
print(para_new)
# Out:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]

# %% [markdown]
# ## stacking

# %%
para_lgbm = {'bagging_fraction': 0.9460815583946198, 'boosting': 'goss', 'device_type': 'cpu', 'drop_rate': 0.19544834548867776, 'extra_trees': True, 'feature_fraction': 0.9808059037360214, 'lambda_l1': 4.582193079266174, 'lambda_l2': 0.8068402557589727, 'learning_rate': 0.0769855835499045, 'metric': 'binary_error', 'min_gain_to_split': 0.9676266908986928, 'num_leaves': 50, 'num_round': 2000, 'num_threads': 4, 'objective': 'binary', 'uniform_drop': True}
para_xgb = {'max_depth': 10, 'eta': 0.02, 'gamma': 1, 'objective': 'binary:logistic', 'eval_metric': ["error"],'nthread':4,}
para_rf = {'bagging_fraction': 0.8622628175801537, 'boosting': 'rf', 'device_type': 'cpu', 'drop_rate': 0.012189396685657418, 'extra_trees': True, 'feature_fraction': 0.9550505045944456, 'lambda_l1': 8.640405964119157, 'lambda_l2': 6.050795522543783, 'learning_rate': 0.04072548365409167, 'metric': 'binary_error', 'min_gain_to_split': 0.047085255255949865, 'num_leaves': 80, 'num_round': 1500, 'num_threads': 4, 'objective': 'binary', 'uniform_drop': False}

num_round_list = [1000, 500, 1000]

# %%
def stacking_train_k_fold(k_fold, train_data, test_data, drop_test_y=True, use_best_eval=True):
        acc_result = list()
        train_pred = np.empty(train_data.shape[0])
        test_pred = np.empty(test_data.shape[0])
        if drop_test_y:
            dtest = test_data.drop(columns=['loan_status'])
        else:
            dtest = test_data

        models = list()
        for train_id, eval_id in k_fold.split(train_data):
            train_df = train_data.loc[train_id]
            eval_df = train_data.loc[eval_id]
            
            train_dataset = lgb.Dataset(train_df.drop(columns='loan_status'), train_df['loan_status'])
            eval_dataset = lgb.Dataset(eval_df.drop(columns='loan_status'), eval_df['loan_status'])
            
            model_lgbm = lgb.train(para_lgbm, train_dataset, num_boost_round=num_round_list[0], valid_sets=[train_dataset, eval_dataset])
            model_xgb = xgb.train(param, train_df, num_round_list[1], (eval_df, 'eval'), (train_df, 'train'))
            model_rf = lgb.train(para_rf, train_dataset, num_boost_round=num_round_list[2], valid_sets=[train_dataset, eval_dataset])
            
            y_pred_lgbm = model_lgbm.predict(eval_df.drop(columns=['loan_status']))
            y_pred_xgb = model_xgb.predict(eval_df.drop(columns=['loan_status']))
            y_pred_rf = model_rf.predict(eval_df.drop(columns=['loan_status']))
            
            y_pred = int((y_pred_lgbm + y_pred_xgb + y_pred_rf) / 3 > 0.5)
            
            acc_result.append(get_loss(eval_df['loan_status'], y_pred))
            
            test_pred += (model_lgbm.predict(dtest) + model_xgb.predict(dtest) + model_rf(dtest))/3
        test_pred /= k_fold.n_splits
        return test_pred

# %%
output = stacking_train_k_fold(kfold, train, test, use_best_eval=True)
test_acc = accuracy_score(test['loan_status'], output.round())
print(f'accuracy_score: {test_acc}')
# Out:
# [LightGBM] [Info] Number of positive: 31731, number of negative: 8269
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003064 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2537
# [LightGBM] [Info] Number of data points in the train set: 40000, number of used features: 141
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.793275 -> initscore=1.344781
# [LightGBM] [Info] Start training from score 1.344781
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	training's binary_error: 0.206725	valid_1's binary_error: 0.1943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	training's binary_error: 0.206725	valid_1's binary_error: 0.1943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	training's binary_error: 0.206725	valid_1's binary_error: 0.1943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	training's binary_error: 0.206725	valid_1's binary_error: 0.1943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	training's binary_error: 0.206725	valid_1's binary_error: 0.1943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	training's binary_error: 0.206725	valid_1's binary_error: 0.1943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	training's binary_error: 0.149525	valid_1's binary_error: 0.1438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	training's binary_error: 0.14775	valid_1's binary_error: 0.1417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	training's binary_error: 0.136825	valid_1's binary_error: 0.1293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	training's binary_error: 0.11235	valid_1's binary_error: 0.1074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	training's binary_error: 0.100225	valid_1's binary_error: 0.0946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	training's binary_error: 0.09575	valid_1's binary_error: 0.0909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]
valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	training's binary_error: 0.08	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	training's binary_error: 0.079925	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	training's binary_error: 0.07995	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	training's binary_error: 0.079925	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	training's binary_error: 0.079925	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	training's binary_error: 0.079975	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	training's binary_error: 0.079925	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	training's binary_error: 0.07985	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	training's binary_error: 0.079825	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	training's binary_error: 0.07975	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	training's binary_error: 0.07975	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	training's binary_error: 0.079875	valid_1's binary_error: 0.0733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	training's binary_error: 0.0799	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	training's binary_error: 0.07985	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	training's binary_error: 0.079775	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	training's binary_error: 0.079675	valid_1's binary_error: 0.0733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	training's binary_error: 0.079725	valid_1's binary_error: 0.0734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's binary_error: 0.0797	valid_1's binary_error: 0.0735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	training's binary_error: 0.079775	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	training's binary_error: 0.079825	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	training's binary_error: 0.07985	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	training's binary_error: 0.079675	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	training's binary_error: 0.07945	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	training's binary_error: 0.07955	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	training's binary_error: 0.079575	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	training's binary_error: 0.0795	valid_1's binary_error: 0.0733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	training's binary_error: 0.0795	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	training's binary_error: 0.079375	valid_1's binary_error: 0.0735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	training's binary_error: 0.079425	valid_1's binary_error: 0.0734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	training's binary_error: 0.079375	valid_1's binary_error: 0.0734
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	training's binary_error: 0.0794	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	training's binary_error: 0.07945	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	training's binary_error: 0.0795	valid_1's binary_error: 0.0733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	training's binary_error: 0.079525	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	training's binary_error: 0.07945	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	training's binary_error: 0.079375	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	training's binary_error: 0.07945	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	training's binary_error: 0.079475	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	training's binary_error: 0.079475	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	training's binary_error: 0.07945	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	training's binary_error: 0.07935	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	training's binary_error: 0.0793	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	training's binary_error: 0.079275	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	training's binary_error: 0.07925	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	training's binary_error: 0.07925	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	training's binary_error: 0.07925	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	training's binary_error: 0.0793	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	training's binary_error: 0.07925	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	training's binary_error: 0.079225	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	training's binary_error: 0.07935	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	training's binary_error: 0.0791	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	training's binary_error: 0.079175	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	training's binary_error: 0.079225	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	training's binary_error: 0.079275	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	training's binary_error: 0.079225	valid_1's binary_error: 0.0732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	training's binary_error: 0.0793	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	training's binary_error: 0.079275	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	training's binary_error: 0.079175	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	training's binary_error: 0.0792	valid_1's binary_error: 0.0731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	training's binary_error: 0.0791	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	training's binary_error: 0.079	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	training's binary_error: 0.07905	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	training's binary_error: 0.078975	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	training's binary_error: 0.07905	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	training's binary_error: 0.079075	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	training's binary_error: 0.07915	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	training's binary_error: 0.07925	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	training's binary_error: 0.0791	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	training's binary_error: 0.07905	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	training's binary_error: 0.0789	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	training's binary_error: 0.07885	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	training's binary_error: 0.078875	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	training's binary_error: 0.0789	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	training's binary_error: 0.0789	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	training's binary_error: 0.079	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	training's binary_error: 0.0789	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	training's binary_error: 0.079075	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	training's binary_error: 0.079025	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	training's binary_error: 0.07905	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	training's binary_error: 0.079175	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	training's binary_error: 0.079075	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	training's binary_error: 0.079075	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	training's binary_error: 0.079025	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	training's binary_error: 0.079	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	training's binary_error: 0.07895	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	training's binary_error: 0.078975	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	training's binary_error: 0.079	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	training's binary_error: 0.079	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	training's binary_error: 0.079	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	training's binary_error: 0.079	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	training's binary_error: 0.079025	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	training's binary_error: 0.079	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	training's binary_error: 0.07895	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	training's binary_error: 0.078925	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	training's binary_error: 0.078925	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	training's binary_error: 0.078875	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	training's binary_error: 0.0789	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	training's binary_error: 0.078875	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	training's binary_error: 0.078775	valid_1's binary_error: 0.0719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	training's binary_error: 0.078775	valid_1's binary_error: 0.0719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	training's binary_error: 0.0788	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	training's binary_error: 0.078675	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	training's binary_error: 0.078675	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	training's binary_error: 0.07865	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	training's binary_error: 0.07875	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	training's binary_error: 0.078825	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	training's binary_error: 0.078775	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	training's binary_error: 0.078775	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	training's binary_error: 0.078675	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	training's binary_error: 0.078575	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	training's binary_error: 0.078525	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	training's binary_error: 0.0786	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	training's binary_error: 0.0786	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	training's binary_error: 0.078475	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	training's binary_error: 0.078475	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	training's binary_error: 0.078525	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	training's binary_error: 0.0786	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	training's binary_error: 0.0786	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	training's binary_error: 0.078625	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	training's binary_error: 0.0786	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	training's binary_error: 0.0786	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	training's binary_error: 0.0786	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	training's binary_error: 0.0786	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	training's binary_error: 0.0785	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	training's binary_error: 0.07855	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [208]	training's binary_error: 0.0786	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	training's binary_error: 0.0787	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	training's binary_error: 0.078625	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	training's binary_error: 0.078575	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212]	training's binary_error: 0.078525	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	training's binary_error: 0.078525	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	training's binary_error: 0.0785	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [215]	training's binary_error: 0.0786	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	training's binary_error: 0.0785	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [217]	training's binary_error: 0.07855	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [218]	training's binary_error: 0.0785	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [219]	training's binary_error: 0.078475	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220]	training's binary_error: 0.07845	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	training's binary_error: 0.078425	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [222]	training's binary_error: 0.078375	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [223]	training's binary_error: 0.078375	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	training's binary_error: 0.078475	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	training's binary_error: 0.0785	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	training's binary_error: 0.078475	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	training's binary_error: 0.078525	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	training's binary_error: 0.078525	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	training's binary_error: 0.0785	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	training's binary_error: 0.078375	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	training's binary_error: 0.078375	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232]	training's binary_error: 0.0783	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	training's binary_error: 0.0783	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [234]	training's binary_error: 0.07835	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	training's binary_error: 0.078325	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	training's binary_error: 0.078325	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	training's binary_error: 0.0784	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	training's binary_error: 0.0784	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	training's binary_error: 0.0784	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	training's binary_error: 0.078375	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	training's binary_error: 0.07835	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	training's binary_error: 0.07835	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	training's binary_error: 0.0784	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	training's binary_error: 0.078375	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	training's binary_error: 0.078325	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	training's binary_error: 0.078425	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	training's binary_error: 0.078475	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	training's binary_error: 0.078375	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	training's binary_error: 0.0782	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	training's binary_error: 0.078175	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	training's binary_error: 0.078275	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	training's binary_error: 0.078275	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	training's binary_error: 0.078225	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	training's binary_error: 0.078225	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	training's binary_error: 0.07815	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	training's binary_error: 0.0782	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	training's binary_error: 0.078325	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	training's binary_error: 0.078425	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	training's binary_error: 0.07835	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	training's binary_error: 0.07835	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	training's binary_error: 0.078325	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	training's binary_error: 0.07825	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	training's binary_error: 0.0784	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	training's binary_error: 0.0784	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	training's binary_error: 0.078375	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	training's binary_error: 0.078375	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	training's binary_error: 0.078325	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	training's binary_error: 0.078375	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	training's binary_error: 0.078275	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	training's binary_error: 0.0783	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	training's binary_error: 0.07815	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	training's binary_error: 0.07815	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	training's binary_error: 0.07815	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	training's binary_error: 0.078125	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	training's binary_error: 0.07805	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	training's binary_error: 0.078075	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	training's binary_error: 0.07825	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	training's binary_error: 0.0782	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	training's binary_error: 0.0782	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	training's binary_error: 0.07815	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	training's binary_error: 0.07815	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	training's binary_error: 0.078125	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	training's binary_error: 0.07815	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	training's binary_error: 0.078225	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	training's binary_error: 0.078125	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	training's binary_error: 0.0782	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	training's binary_error: 0.0781	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	training's binary_error: 0.078125	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	training's binary_error: 0.07805	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	training's binary_error: 0.07805	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	training's binary_error: 0.07805	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	training's binary_error: 0.07805	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	training's binary_error: 0.07795	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	training's binary_error: 0.077925	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	training's binary_error: 0.078025	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	training's binary_error: 0.077975	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	training's binary_error: 0.078	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	training's binary_error: 0.077975	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	training's binary_error: 0.078075	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	training's binary_error: 0.0781	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	training's binary_error: 0.078075	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	training's binary_error: 0.078	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	training's binary_error: 0.07795	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	training's binary_error: 0.077925	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	training's binary_error: 0.07785	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	training's binary_error: 0.07795	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	training's binary_error: 0.077975	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	training's binary_error: 0.077925	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	training's binary_error: 0.077775	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [310]	training's binary_error: 0.077775	valid_1's binary_error: 0.0722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	training's binary_error: 0.07775	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [312]	training's binary_error: 0.077675	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	training's binary_error: 0.07765	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	training's binary_error: 0.0776	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [315]	training's binary_error: 0.0776	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	training's binary_error: 0.077725	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	training's binary_error: 0.077725	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	training's binary_error: 0.07775	valid_1's binary_error: 0.0723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	training's binary_error: 0.077775	valid_1's binary_error: 0.072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	training's binary_error: 0.077725	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	training's binary_error: 0.077875	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	training's binary_error: 0.077825	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	training's binary_error: 0.077775	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	training's binary_error: 0.0778	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	training's binary_error: 0.077725	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	training's binary_error: 0.077725	valid_1's binary_error: 0.0721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	training's binary_error: 0.077775	valid_1's binary_error: 0.0721
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1916]	training's binary_error: 0.075525	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1917]	training's binary_error: 0.07555	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1918]	training's binary_error: 0.075525	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1919]	training's binary_error: 0.075525	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1920]	training's binary_error: 0.07545	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1921]	training's binary_error: 0.0754	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1922]	training's binary_error: 0.07545	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1923]	training's binary_error: 0.075475	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1924]	training's binary_error: 0.075525	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1925]	training's binary_error: 0.07545	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1926]	training's binary_error: 0.07555	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1927]	training's binary_error: 0.075425	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1928]	training's binary_error: 0.07545	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1929]	training's binary_error: 0.07545	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1930]	training's binary_error: 0.075525	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1931]	training's binary_error: 0.075525	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1932]	training's binary_error: 0.0755	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1933]	training's binary_error: 0.075475	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1934]	training's binary_error: 0.0755	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1935]	training's binary_error: 0.07555	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1936]	training's binary_error: 0.075525	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1937]	training's binary_error: 0.075575	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1938]	training's binary_error: 0.075525	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1939]	training's binary_error: 0.075525	valid_1's binary_error: 0.073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1940]	training's binary_error: 0.075525	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1941]	training's binary_error: 0.075475	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1942]	training's binary_error: 0.075425	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1943]	training's binary_error: 0.075425	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1944]	training's binary_error: 0.07545	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1945]	training's binary_error: 0.07545	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1946]	training's binary_error: 0.0754	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1947]	training's binary_error: 0.075425	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1948]	training's binary_error: 0.075425	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1949]	training's binary_error: 0.07535	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1950]	training's binary_error: 0.075375	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1951]	training's binary_error: 0.075425	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1952]	training's binary_error: 0.075425	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1953]	training's binary_error: 0.075425	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1954]	training's binary_error: 0.07545	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1955]	training's binary_error: 0.07535	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1956]	training's binary_error: 0.07535	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1957]	training's binary_error: 0.075325	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1958]	training's binary_error: 0.07535	valid_1's binary_error: 0.0725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1959]	training's binary_error: 0.0753	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1960]	training's binary_error: 0.0753	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1961]	training's binary_error: 0.0753	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1962]	training's binary_error: 0.0754	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1963]	training's binary_error: 0.07535	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1964]	training's binary_error: 0.075375	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1965]	training's binary_error: 0.0754	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1966]	training's binary_error: 0.07535	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1967]	training's binary_error: 0.07535	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1968]	training's binary_error: 0.0753	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1969]	training's binary_error: 0.0753	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1970]	training's binary_error: 0.0753	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1971]	training's binary_error: 0.075275	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1972]	training's binary_error: 0.075275	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1973]	training's binary_error: 0.0752	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1974]	training's binary_error: 0.07515	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1975]	training's binary_error: 0.0752	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1976]	training's binary_error: 0.075225	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1977]	training's binary_error: 0.07515	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1978]	training's binary_error: 0.07515	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1979]	training's binary_error: 0.075175	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1980]	training's binary_error: 0.075125	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1981]	training's binary_error: 0.07515	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1982]	training's binary_error: 0.07525	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1983]	training's binary_error: 0.07525	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1984]	training's binary_error: 0.07525	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1985]	training's binary_error: 0.0752	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1986]	training's binary_error: 0.07525	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1987]	training's binary_error: 0.075225	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1988]	training's binary_error: 0.075275	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1989]	training's binary_error: 0.075125	valid_1's binary_error: 0.0724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1990]	training's binary_error: 0.0753	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1991]	training's binary_error: 0.075325	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1992]	training's binary_error: 0.07525	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [1993]	training's binary_error: 0.07525	valid_1's binary_error: 0.0729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1994]	training's binary_error: 0.0752	valid_1's binary_error: 0.0728
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1995]	training's binary_error: 0.07525	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1996]	training's binary_error: 0.075225	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1997]	training's binary_error: 0.0752	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1998]	training's binary_error: 0.07515	valid_1's binary_error: 0.0727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1999]	training's binary_error: 0.075175	valid_1's binary_error: 0.0726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	training's binary_error: 0.075175	valid_1's binary_error: 0.0725
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/miniconda3/envs/ml/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-220-31f783bb5fd2> in <module>
# ----> 1 output = stacking_train_k_fold(kfold, train, test, use_best_eval=True)
#       2 test_acc = accuracy_score(test['loan_status'], output.round())
#       3 print(f'accuracy_score: {test_acc}')
#
# <ipython-input-219-ac3a1057fbdc> in stacking_train_k_fold(k_fold, train_data, test_data, drop_test_y, use_best_eval)
#      17
#      18             model_lgbm = lgb.train(para_lgbm, train_dataset, num_boost_round=num_round_list[0], valid_sets=[train_dataset, eval_dataset])
# ---> 19             model_xgb = xgb.train(param, train_df, num_round_list[1], (eval_df, 'eval'), (train_df, 'train'))
#      20             model_rf = lgb.train(para_rf, train_dataset, num_boost_round=num_round_list[2], valid_sets=[train_dataset, eval_dataset])
#      21
#
# /opt/miniconda3/envs/ml/lib/python3.8/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     187     Booster : a trained booster model
#     188     """
# --> 189     bst = _train_internal(params, dtrain,
#     190                           num_boost_round=num_boost_round,
#     191                           evals=evals,
#
# /opt/miniconda3/envs/ml/lib/python3.8/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      49     evals = list(evals)
#      50
# ---> 51     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#      52
#      53     if xgb_model is not None:
#
# /opt/miniconda3/envs/ml/lib/python3.8/site-packages/xgboost/training.py in <listcomp>(.0)
#      49     evals = list(evals)
#      50
# ---> 51     bst = Booster(params, [dtrain] + [d[0] for d in evals])
#      52
#      53     if xgb_model is not None:
#
# /opt/miniconda3/envs/ml/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /opt/miniconda3/envs/ml/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 0
